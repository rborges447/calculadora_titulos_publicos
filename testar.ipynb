# %% [markdown]
# # Teste: Visualização do cálculo de Hedge DAP
#
# Este notebook contém todas as funções necessárias para calcular o hedge DAP e o método `_calcular_hedge_dap` da classe NTNB.

# %%
from titulospub.core.dap.calculo_dap import *
from titulospub import NTNB

# %%
calculo_financeiro_dap(taxa=7.56, 
                       codigo="DAPQ32", 
                       data_liquidacao=None, data_vencimento=None, feriados=None)
# Out:
# np.float64(113900.26679748102)

# %%
dap = dv01_dap(taxa=7.56,
        codigo="DAPQ32",
        )

# %%
B = NTNB("2032-08-15", quantidade=1)
dvb = B._dv01 * 10000
dvb/ dap
# Out:
# [OK] Usando cache existente de ANBIMAS completo.
# [OK] Usando cache existente de BMF completo.
# np.float64(322.74804986511424)
